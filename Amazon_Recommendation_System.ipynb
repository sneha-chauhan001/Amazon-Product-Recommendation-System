# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('amazon.csv')

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   str
#  4   actual_price         1465 non-null   str
#  5   discount_percentage  1465 non-null   str
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# dtypes: str(16)
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Unique Products:", df['product_id'].nunique())
print("Unique Users:", df['user_id'].nunique())
print("Unique Categories:", df['category'].nunique())
# Out:
# Unique Products: 1351
# Unique Users: 1194
# Unique Categories: 211

# %%
df.dropna(subset=['rating_count'], inplace=True)

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 4.1    244
# 4.3    230
# 4.2    228
# 4.0    129
# 3.9    123
# 4.4    123
# 3.8     86
# 4.5     75
# 4       52
# 3.7     42
# 3.6     35
# 3.5     26
# 4.6     17
# 3.3     16
# 3.4     10
# 4.7      6
# 3.1      4
# 4.8      3
# 3.2      2
# 5.0      2
# 3.0      2
# 2.8      2
# 2.3      1
# |        1
# 2        1
# 3        1
# 2.6      1
# 2.9      1
# Name: count, dtype: int64

# %%
df['category'].value_counts().head(10)
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                        231
# Electronics|WearableTechnology|SmartWatches                                                               76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                      68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                             63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                              52
# Electronics|HomeTheater,TV&Video|Accessories|RemoteControls                                               49
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|MixerGrinders                                  27
# Electronics|HomeTheater,TV&Video|Accessories|Cables|HDMICables                                            24
# ...

# %%
df = df[pd.to_numeric(df['rating'], errors='coerce').notnull()]
df['rating'] = df['rating'].astype(float)

# %%
df['rating'].dtype
# Out:
# dtype('float64')

# %%
df['combined_features'] = df['product_name'] + ' ' + df['category'] + ' ' + df['about_product']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['combined_features'])

# %%
tfidf_matrix.shape
# Out:
# (1465, 10361)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim.shape
# Out:
# (1465, 1465)

# %%
indices = pd.Series(df.index, index=df['product_name']).drop_duplicates()

# %%
def recommend_products(product_name, top_n=5):
    idx = indices[product_name]

    if isinstance(idx, pd.Series):
        idx = idx.iloc[0]

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]
    product_indices = [i[0] for i in sim_scores]

    return df['product_name'].iloc[product_indices]

# %%
recommend_products(df['product_name'].iloc[123])
# Out:
# 292    Hisense 126 cm (50 inches) Bezelless Series 4K...
# 323    TCL 108 cm (43 inches) 4K Ultra HD Certified A...
# 94     TCL 100 cm (40 inches) Full HD Certified Andro...
# 61     Samsung 108 cm (43 inches) Crystal 4K Neo Seri...
# 280    Toshiba 108 cm (43 inches) V Series Full HD Sm...
# Name: product_name, dtype: str

# %% [markdown]
# # Content-Based Recommendation System
#
# ## Overview
# Content-Based Recommendation System recommends products based on the features of the products themselves. It analyzes product information such as product name, category, and description, and recommends items that are similar to the one selected by the user.
#
# In this project, we use:
# - **Product Name**
# - **Category**
# - **About Product**
#
# to create a combined feature set for each product.
#
# ---
#
# ## Steps Performed
#
# ### 1. Feature Combination
# The important product-related columns were merged into a single column named `combined_features`.
#
# Purpose:
# To create a complete textual representation of each product.
#
# ---
#
# ### 2. TF-IDF Vectorization
# TF-IDF (Term Frequency - Inverse Document Frequency) was applied on the combined features.
#
# Purpose:
# To convert text data into numerical vectors so that the machine can process and compare products.
#
# ---
#
# ### 3. Cosine Similarity Calculation
# Cosine similarity was calculated between all products.
#
# Purpose:
# To measure how similar one product is to another.
#
# Range:
# - **0** → Completely different
# - **1** → Exactly similar
#
# ---
#
# ### 4. Recommendation Function
# A function was created to:
# - Take a product name as input
# - Find its similarity with all products
# - Return the top 5 most similar products
#
# ---
#
# ## Result
# The model successfully recommends similar products.
#
# Example:
# If the input product is a **Television**, the output also recommends other televisions from similar brands and categories.
#
# This shows that the content-based recommendation system is working correctly.

# %%
user_item_matrix = df.pivot_table(index='user_id', columns='product_id', values='rating')

# %%
user_item_matrix.head()
# Out:
# product_id                                          B002PD61Y4  B002SZEOLG  \
# user_id
# AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZAH...         NaN         NaN
# AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS6...         NaN         NaN
# AE242TR3GQ6TYC6W4SJ5UYYKBTYQ                               NaN         NaN
# AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25J...         NaN         NaN
# AE2JTMRKTUOIVIZWS2WDGTMNTU4Q,AF4QXCB32VC2DVE7O3...         NaN         NaN
#
# product_id                                          B003B00484  B003L62T7W  \
# user_id
# AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZAH...         NaN         NaN
# AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS6...         NaN         NaN
# AE242TR3GQ6TYC6W4SJ5UYYKBTYQ                               NaN         NaN
# AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25J...         NaN         NaN
# AE2JTMRKTUOIVIZWS2WDGTMNTU4Q,AF4QXCB32VC2DVE7O3...         NaN         NaN
#
# ...

# %%
user_item_matrix.shape
# Out:
# (1193, 1350)

# %%
user_item_matrix.notnull().sum().sum()
# Out:
# np.int64(1360)

# %%
user_item_matrix.stack().head(10)
# Out:
# user_id                                                                                                                                                                        product_id
# AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZAHJK6NGYHFMA,AGYURQ3476BNT4D2O46THXEUY3SA,AFPMBSBIEX45OQ6UCQWPDG55GWLQ,AGWJU3WUQBDQYPSYAJSR3AKBLCOA,AEOVUNFCIFV223O536GVW5JHZKOA  B002PD61Y4   NaN
#                                                                                                                                                                                B002SZEOLG   NaN
#                                                                                                                                                                                B003B00484   NaN
#                                                                                                                                                                                B003L62T7W   NaN
# ...

# %%
user_item_matrix.stack().reset_index().head(10)
# Out:
#                                              user_id  product_id   0
# 0  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B002PD61Y4 NaN
# 1  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B002SZEOLG NaN
# 2  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B003B00484 NaN
# 3  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B003L62T7W NaN
# 4  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B004IO5BMQ NaN
# 5  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B005FYNT3G NaN
# 6  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B005LJQMCK NaN
# 7  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B005LJQMZC NaN
# 8  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B006LW0WDQ NaN
# 9  AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZA...  B0073QGKAS NaN

# %%
df['rating'].dtype
# Out:
# dtype('float64')

# %%
df[['user_id','product_id','rating']].head(10)
# Out:
#                                              user_id  product_id  rating
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...  B07JW9H4J1     4.2
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...  B098NS6PVG     4.0
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...  B096MSW6CT     3.9
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...  B08HDJ86NZ     4.2
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...  B08CF3B7N1     4.2
# 5  AEQ2YMXSZWEOHK2EHTNLOS56YTZQ,AGRVINWECNY7323CW...  B08Y1TFSP6     3.9
# 6  AG7C6DAADCTRQJG2BRS3RIKDT52Q,AFU7BOMPVJ7Q3TTA4...  B08WRWPM22     4.1
# 7  AHW6E5LQ2BDYOIVLAJGDH45J5V5Q,AF74RSGCHPZITVFSZ...  B08DDRGWTJ     4.3
# 8  AGV3IEFANZCKECFGUM42MRH5FNOA,AEBO7NWCNXKT4AESA...  B008IFXQFU     4.2
# 9  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...  B082LZGK39     4.0

# %%
df[['user_id','product_id','rating']].isnull().sum()
# Out:
# user_id       0
# product_id    0
# rating        0
# dtype: int64

# %%
user_item_matrix.iloc[:10, :10]
# Out:
# product_id                                          B002PD61Y4  B002SZEOLG  \
# user_id
# AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZAH...         NaN         NaN
# AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS6...         NaN         NaN
# AE242TR3GQ6TYC6W4SJ5UYYKBTYQ                               NaN         NaN
# AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25J...         NaN         NaN
# AE2JTMRKTUOIVIZWS2WDGTMNTU4Q,AF4QXCB32VC2DVE7O3...         NaN         NaN
# AE2OFVZSIE6KSBAPG6GMKCER35LA,AFEOAY5PB4XEYIOL6D...         NaN         NaN
# AE2QS54KQW357EMHTCIX34UBB2TA,AFGABX3WXI4C644LQX...         NaN         NaN
# AE2TSJXRS5BXE6X7WFS7HOFJKCOQ,AEQTFT2S7RDVYEGOX5...         NaN         NaN
# AE2XBDOYDMXVHS6NWFKR363SXNEQ,AFEWNQ3WHCXFV334RK...         NaN         NaN
# AE2XMB6CEF4SCPYQI75GHNYEAXIA,AGGZZQ5IGA5QAIGYO5...         NaN         NaN
#
# product_id                                          B003B00484  B003L62T7W  \
# user_id
# ...

# %%
user_item_filled = user_item_matrix.fillna(0)

# %%
user_item_filled.iloc[:10, :10]
# Out:
# product_id                                          B002PD61Y4  B002SZEOLG  \
# user_id
# AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZAH...         0.0         0.0
# AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS6...         0.0         0.0
# AE242TR3GQ6TYC6W4SJ5UYYKBTYQ                               0.0         0.0
# AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25J...         0.0         0.0
# AE2JTMRKTUOIVIZWS2WDGTMNTU4Q,AF4QXCB32VC2DVE7O3...         0.0         0.0
# AE2OFVZSIE6KSBAPG6GMKCER35LA,AFEOAY5PB4XEYIOL6D...         0.0         0.0
# AE2QS54KQW357EMHTCIX34UBB2TA,AFGABX3WXI4C644LQX...         0.0         0.0
# AE2TSJXRS5BXE6X7WFS7HOFJKCOQ,AEQTFT2S7RDVYEGOX5...         0.0         0.0
# AE2XBDOYDMXVHS6NWFKR363SXNEQ,AFEWNQ3WHCXFV334RK...         0.0         0.0
# AE2XMB6CEF4SCPYQI75GHNYEAXIA,AGGZZQ5IGA5QAIGYO5...         0.0         0.0
#
# product_id                                          B003B00484  B003L62T7W  \
# user_id
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
user_similarity = cosine_similarity(user_item_filled)

# %%
user_similarity.shape
# Out:
# (1193, 1193)

# %%
user_similarity_df = pd.DataFrame(
    user_similarity,
    index=user_item_filled.index,
    columns=user_item_filled.index
)

# %%
user_similarity_df.head()
# Out:
# user_id                                             AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZAHJK6NGYHFMA,AGYURQ3476BNT4D2O46THXEUY3SA,AFPMBSBIEX45OQ6UCQWPDG55GWLQ,AGWJU3WUQBDQYPSYAJSR3AKBLCOA,AEOVUNFCIFV223O536GVW5JHZKOA  \
# user_id
# AE22Y3KIS7SE6LI3HE2VS6WWPU4Q,AHWEYO2IJ5I5GDWZAH...                                                1.0
# AE23RS3W7GZO7LHYKJU6KSKVM4MQ,AEQUNEY6GQOTEGUMS6...                                                0.0
# AE242TR3GQ6TYC6W4SJ5UYYKBTYQ                                                                      0.0
# AE27UOZENYSWCQVQRRUQIV2ZM7VA,AGMYSLV6NNOAYES25J...                                                0.0
# AE2JTMRKTUOIVIZWS2WDGTMNTU4Q,AF4QXCB32VC2DVE7O3...                                                0.0
#
# ...

# %%
def recommend_collaborative(user_id, top_n=5):
    similar_users = user_similarity_df[user_id].sort_values(ascending=False)[1:top_n+1]

    similar_users_products = user_item_filled.loc[similar_users.index]

    recommended_products = similar_users_products.mean().sort_values(ascending=False)

    return recommended_products.head(top_n)

# %%
recommend_collaborative(df['user_id'].iloc[0])
# Out:
# product_id
# B0BJ6P3LSK    0.90
# B07ZR4S1G4    0.88
# B09HSKYMB3    0.86
# B008LN8KDM    0.86
# B07KNM95JK    0.82
# dtype: float64

# %%
df[df['product_id'].isin(recommend_collaborative(df['user_id'].iloc[0]).index)][['product_id','product_name']].drop_duplicates()
# Out:
#       product_id                                       product_name
# 202   B07ZR4S1G4  Universal Remote Control for All Sony TV for A...
# 558   B09HSKYMB3  MI REDMI 9i Sport (Carbon Black, 64 GB) (4 GB ...
# 987   B07KNM95JK  Foxin FTC 12A / Q2612A Black Laser Toner Cartr...
# 1207  B008LN8KDM  Philips GC1920/28 1440-Watt Non-Stick Soleplat...
# 1416  B0BJ6P3LSK  Aqua d pure Active Copper 12-L RO+UV Water Fil...

# %% [markdown]
# ## Collaborative Filtering
#
# In this section, we implemented the **Collaborative Filtering Recommendation System**.
# Unlike content-based filtering, collaborative filtering recommends products based on the behavior and preferences of **similar users**.
#
# ### Steps performed:
# 1. Created a **User-Item Matrix** using `user_id`, `product_id`, and `rating`.
# 2. Filled missing values (`NaN`) with `0` to represent no interaction.
# 3. Applied **Cosine Similarity** to measure similarity between users.
# 4. Built a recommendation function to:
#    - Find the most similar users.
#    - Collect their highly rated products.
#    - Recommend top products to the selected user.
#
# ### Observation:
# The dataset was highly sparse, meaning most users rated only a small number of products.
# Because of this, user-user similarity was often low.
#
# ### Result:
# The system successfully generated recommendations based on similar user behavior.
# However, due to sparse interactions, collaborative filtering may be less effective than content-based filtering for this dataset.
#
# This limitation is common in real-world recommendation systems and is known as the **sparsity problem**.

# %%
def hybrid_recommend(product_name, user_id, top_n=5):

    content_recs = recommend_products(product_name, top_n).tolist()

    collaborative_recs = recommend_collaborative(user_id, top_n).index.tolist()

    collaborative_names = df[df['product_id'].isin(collaborative_recs)]['product_name'].drop_duplicates().tolist()

    final_recommendations = list(dict.fromkeys(content_recs + collaborative_names))

    return final_recommendations[:top_n]

# %%
hybrid_recommend(
    df['product_name'].iloc[123],
    df['user_id'].iloc[0]
)
# Out:
# ['Hisense 126 cm (50 inches) Bezelless Series 4K Ultra HD Smart LED Google TV 50A6H (Black)',
#  'TCL 108 cm (43 inches) 4K Ultra HD Certified Android Smart LED TV 43P615 (Black)',
#  'TCL 100 cm (40 inches) Full HD Certified Android R Smart LED TV 40S6505 (Black)',
#  'Samsung 108 cm (43 inches) Crystal 4K Neo Series Ultra HD Smart LED TV UA43AUE65AKXXL (Black)',
#  'Toshiba 108 cm (43 inches) V Series Full HD Smart Android LED TV 43V35KP (Silver)']

# %% [markdown]
# ## Hybrid Recommendation System
#
# In this section, we implemented the **Hybrid Recommendation System** by combining both Content-Based Filtering and Collaborative Filtering.
#
# Hybrid recommendation takes advantage of:
# - **Content-Based Filtering** for personalized recommendations based on product features.
# - **Collaborative Filtering** for discovery of products based on similar user behavior.
#
# ### Steps performed:
# 1. Generated content-based recommendations using product features such as product name, category, and description.
# 2. Generated collaborative recommendations using user-product-rating interactions.
# 3. Converted collaborative product IDs into product names.
# 4. Combined both recommendation lists.
# 5. Removed duplicate recommendations.
#
# ### Observation:
# The hybrid model provided a better balance between personalization and discovery.
#
# ### Result:
# Hybrid filtering produced more balanced and practical recommendations by reducing the limitations of both individual systems.

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Sample product and user
sample_product = df['product_name'].iloc[0]
sample_user = df['user_id'].iloc[0]

# New ground truth: top-rated products globally
liked_products = df[df['rating'] >= 4]['product_name'].drop_duplicates().head(20).tolist()

# Get recommendations
content_recs = recommend_products(sample_product, top_n=5).tolist()

collab_ids = recommend_collaborative(sample_user, top_n=5).index.tolist()
collab_recs = df[df['product_id'].isin(collab_ids)]['product_name'].drop_duplicates().tolist()

hybrid_recs = hybrid_recommend(sample_product, sample_user, top_n=5)


# Evaluation function
def evaluate_system(recommended, actual):
    all_products = list(set(recommended + actual))

    y_true = [1 if product in actual else 0 for product in all_products]
    y_pred = [1 if product in recommended else 0 for product in all_products]

    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)

    return precision, recall, f1


# Calculate scores
content_precision, content_recall, content_f1 = evaluate_system(content_recs, liked_products)
collab_precision, collab_recall, collab_f1 = evaluate_system(collab_recs, liked_products)
hybrid_precision, hybrid_recall, hybrid_f1 = evaluate_system(hybrid_recs, liked_products)


# Print scores
print("Content-Based:")
print("Precision:", content_precision)
print("Recall:", content_recall)
print("F1 Score:", content_f1)

print("\nCollaborative:")
print("Precision:", collab_precision)
print("Recall:", collab_recall)
print("F1 Score:", collab_f1)

print("\nHybrid:")
print("Precision:", hybrid_precision)
print("Recall:", hybrid_recall)
print("F1 Score:", hybrid_f1)
# Out:
# Content-Based:
# Precision: 0.25
# Recall: 0.05
# F1 Score: 0.08333333333333333
#
# Collaborative:
# Precision: 0.0
# Recall: 0.0
# F1 Score: 0.0
#
# Hybrid:
# Precision: 0.2
# Recall: 0.05
# F1 Score: 0.08

# %%
systems = ['Content-Based', 'Collaborative', 'Hybrid']
f1_scores = [content_f1, collab_f1, hybrid_f1]

plt.figure(figsize=(8,5))
plt.bar(systems, f1_scores)

plt.xlabel('Recommendation Systems')
plt.ylabel('F1 Score')
plt.title('F1 Score Comparison of Recommendation Systems')

plt.show()

# %%
systems = ['Content-Based', 'Collaborative', 'Hybrid']
precision_scores = [content_precision, collab_precision, hybrid_precision]

plt.figure(figsize=(8,5))
plt.bar(systems, precision_scores)

plt.title('Precision Comparison of Recommendation Systems')
plt.xlabel('Recommendation Systems')
plt.ylabel('Precision')

plt.show()

# %% [markdown]
# Precision measures the correctness of recommendations. It tells us out of all recommended products, how many were actually relevant. In my project, Content-Based Filtering achieved the highest precision, while Collaborative Filtering had the lowest precision.

# %%
systems = ['Content-Based', 'Collaborative', 'Hybrid']
recall_scores = [content_recall, collab_recall, hybrid_recall]

plt.figure(figsize=(8,5))
plt.bar(systems, recall_scores)

plt.title('Recall Comparison of Recommendation Systems')
plt.xlabel('Recommendation Systems')
plt.ylabel('Recall')

plt.show()

# %% [markdown]
# Recall measures how many relevant products the recommendation system was able to find. In this project, Content-Based and Hybrid Filtering achieved similar recall, while Collaborative Filtering had the lowest recall because of sparse user interaction data.

# %%
systems = ['Content-Based', 'Collaborative', 'Hybrid']
f1_scores = [content_f1, collab_f1, hybrid_f1]

plt.figure(figsize=(8,5))
plt.bar(systems, f1_scores)

plt.title('F1 Score Comparison of Recommendation Systems')
plt.xlabel('Recommendation Systems')
plt.ylabel('F1 Score')

plt.show()

# %% [markdown]
# F1-score is the balance between Precision and Recall. It is considered the final performance metric because it considers both correctness and completeness of recommendations. Content-Based Filtering achieved the highest F1-score, followed closely by Hybrid Filtering.

# %% [markdown]
# Evaluation Result
#
# In this section, the recommendation systems were evaluated using Precision, Recall, and F1-score, which are standard machine learning evaluation metrics.
#
# These metrics were used to measure how accurately each system recommended relevant products.
#
# Precision measures how many recommended products were actually relevant.
# Recall measures how many relevant products were successfully recommended.
# F1-score gives the balanced result of both precision and recall.
#
# Based on the graph:
#
# Content-Based Filtering achieved the highest F1-score.
# Hybrid Recommendation System performed very close to Content-Based Filtering.
# Collaborative Filtering performed weakly and gave a score of zero.
#
# This shows that for this dataset, Content-Based Filtering was more effective.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Metrics
metrics = ['Precision', 'Recall', 'F1 Score']

content = [content_precision, content_recall, content_f1]
collaborative = [collab_precision, collab_recall, collab_f1]
hybrid = [hybrid_precision, hybrid_recall, hybrid_f1]

x = np.arange(len(metrics))
width = 0.25

plt.figure(figsize=(8,5))

plt.bar(x - width, content, width, label='Content-Based')
plt.bar(x, collaborative, width, label='Collaborative')
plt.bar(x + width, hybrid, width, label='Hybrid')

plt.xticks(x, metrics)
plt.ylabel("Score")
plt.title("Comparison of Recommendation Systems")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Dataset Observation
#
# The Amazon dataset used in this project contains strong product-related features such as product name, category, and product description.
#
# Because of these rich textual features, Content-Based Filtering performed better.
#
# The dataset had limited user-product interaction data, which created the sparsity problem in Collaborative Filtering.
#
# Due to this, Collaborative Filtering could not find strong user similarity and performed poorly.
#
# Hybrid Filtering still gave balanced performance because it combined both methods.

# %% [markdown]
# Best Recommendation System
#
# Based on this project:
#
# Content-Based Filtering performed best because the dataset had rich product features.
# Collaborative Filtering performed weakly due to sparse rating data.
# Hybrid Filtering gave balanced results but was slightly affected by the weak collaborative part.
#
# Therefore, for this dataset, Content-Based Filtering is considered the best-performing recommendation system.
#
# However, in general real-world platforms, Hybrid Filtering is usually preferred.

# %% [markdown]
# Future Scope
#
# The recommendation system can be improved in future by:
#
# Using larger and more diverse datasets.
# Adding user browsing history and wishlist data.
# Adding purchase history and click behavior.
# Reducing sparsity by collecting more user interactions.
# Applying Deep Learning-based recommendation models.
# Improving cold-start handling for new users and products.
# Adding real-time recommendation updates.
#
# With richer user behavior data, Collaborative and Hybrid systems can perform much better.

# %% [markdown]
# Conclusion
#
# In this project, three recommendation systems were implemented and evaluated: Content-Based Filtering, Collaborative Filtering, and Hybrid Filtering.
#
# The systems were tested using Precision, Recall, and F1-score to measure recommendation quality.
#
# The Content-Based Recommendation System performed best because the dataset contained strong product features such as product name, category, and product description, which helped in finding similarity more effectively.
#
# The Collaborative Filtering system performed weakly because it depended mainly on ratings, and the dataset had sparse user interaction data. This caused the sparsity problem.
#
# The Hybrid Recommendation System gave balanced performance and stayed close to Content-Based Filtering, but its performance was affected by the weaker collaborative part.
#
# This project shows that recommendation system performance depends heavily on the type of dataset used.
#
# In real-world platforms like Amazon, Hybrid Recommendation Systems are commonly used because they combine both content information and user behavior for better personalization and discovery.
